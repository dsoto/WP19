# %% [markdown]
# Asei has a very large apparent leap in consumption.
# I think this is because the energy data wasn't collected for a while.
# When the data did start collecting again, it showed a large jump.
# With my current discrete difference way of collecting the data, it is interpreted as a day with very large consumption.
#
# - TODO: How do I keep this from messing with my statistics?
# - TODO: How do I show the cause of the anomaly?

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import WP19_analysis as wpa
import seaborn as sns
import matplotlib.pyplot as plt

# %%
energy = wpa.load_timeseries_file('asei-clean.csv')
energy = energy.groupby(energy.index).last()
energy['kWh export'].plot()
